# %%
import ampworks as amp

# %%
data = amp.read_table(
    'sample.txt',
    extra_columns={
        'Current (A)': None,
        'Temperature': float,
        'Notes': None,
        'missing': None,
        'Cycle': int,
    },
)

# %%
data

# %%
data['Temperature'].dtype == 'float64'
